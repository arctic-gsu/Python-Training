# %% [markdown]
#  # Loading data from different sources

# %% [markdown]
# ## 1. Loading from CSV

# %%
import pandas as pd

# %%
# reading data from csv
data = pd.read_csv("../data/georgia-history.csv")
data.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-07    GA  17906.0         15598.0              1         2308.0
# 1  2021-03-06    GA  17905.0         15597.0             90         2308.0
# 2  2021-03-05    GA  17815.0         15526.0             65         2289.0
# 3  2021-03-04    GA  17750.0         15462.0            125         2288.0
# 4  2021-03-03    GA  17625.0         15349.0            145         2276.0
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0       56797.0                 56797.0                 2008.0
# 1       56762.0                 56762.0                 2071.0
# 2       56627.0                 56627.0                 2099.0
# 3       56512.0                 56512.0                 2191.0
# 4       56369.0                 56369.0                 2299.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %% [markdown]
# ## 2. Loading from URL

# %%
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"

# reading data from url
data = pd.read_csv(url)
data.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# ## 3. Loading from Microsoft Excel

# %%
# reading data from excel. Need to install package openpyxl. Can install using "pip install openpyxl"
data = pd.read_excel("../data/georgia-history.xlsx")
data.head()
# Out:
#     date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  44262    GA  17906.0         15598.0              1         2308.0
# 1  44261    GA  17905.0         15597.0             90         2308.0
# 2  44260    GA  17815.0         15526.0             65         2289.0
# 3  44259    GA  17750.0         15462.0            125         2288.0
# 4  44258    GA  17625.0         15349.0            145         2276.0
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0       56797.0                 56797.0                 2008.0
# 1       56762.0                 56762.0                 2071.0
# 2       56627.0                 56627.0                 2099.0
# 3       56512.0                 56512.0                 2191.0
# 4       56369.0                 56369.0                 2299.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# 0                    35  ...           7359069                     18827
# ...

# %% [markdown]
# ## 4. Loading from JSON file

# %%
# reading data from json
data = pd.read_json("../data/georgia-history.json")
data.head()
# Out:
#         date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0 2021-03-07    GA  17906.0         15598.0              1         2308.0
# 1 2021-03-06    GA  17905.0         15597.0             90         2308.0
# 2 2021-03-05    GA  17815.0         15526.0             65         2289.0
# 3 2021-03-04    GA  17750.0         15462.0            125         2288.0
# 4 2021-03-03    GA  17625.0         15349.0            145         2276.0
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0       56797.0                 56797.0                 2008.0
# 1       56762.0                 56762.0                 2071.0
# 2       56627.0                 56627.0                 2099.0
# 3       56512.0                 56512.0                 2191.0
# 4       56369.0                 56369.0                 2299.0
#
#    hospitalizedIncrease  ...  totalTestResults totalTestResultsIncrease  \
# ...

# %% [markdown]
# ## 5. Loading from XML file

# %%
# reading data from xml
data = pd.read_xml("../data/georgia-history.xml")
data.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-07    GA  17906.0         15598.0              1         2308.0
# 1  2021-03-06    GA  17905.0         15597.0             90         2308.0
# 2  2021-03-05    GA  17815.0         15526.0             65         2289.0
# 3  2021-03-04    GA  17750.0         15462.0            125         2288.0
# 4  2021-03-03    GA  17625.0         15349.0            145         2276.0
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0       56797.0                 56797.0                 2008.0
# 1       56762.0                 56762.0                 2071.0
# 2       56627.0                 56627.0                 2099.0
# 3       56512.0                 56512.0                 2191.0
# 4       56369.0                 56369.0                 2299.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %% [markdown]
# For more data types reference visit:<br/>
# https://pandas.pydata.org/docs/reference/io.html# <br/>
# https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %%
# Example 1. Read the data meminfo.csv from data folder and save it to the pickle format.
# Refer: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_pickle.html#pandas.DataFrame.to_pickle
